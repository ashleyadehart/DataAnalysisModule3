# %% [markdown]
# # SQL Murder Mystery

# %%
# Import Python Libraries
from IPython.display import Image, display

# %%
# Ran a SQL query that searches for crimes that have occured in SQL City
display(Image(filename='screenshots/Screenshot 2026-05-24 101902.png'))

# %%
# Ran a SQL query that searches for murders that occured in SQL City on 01/15/2018
display(Image(filename='screenshots/Screenshot 2026-05-24 102342.png'))

# %% [markdown]
# Since security footage showed two witnesses, I decided to look up more information about them.

# %%
# Ran a SQL query that shows the details of a witness named Annabel
display(Image(filename='screenshots/Screenshot 2026-05-24 102935.png'))

# %% [markdown]
# I discovered that the person table combined first and last name in one of the columns. Therefore, I ran a different query that used the like and wildcard functions.

# %%
# Ran a SQL query that shows the details of a witness named Annabel using like function and wildcard characters
display(Image(filename='screenshots/Screenshot 2026-05-24 103530.png'))

# %%
# Ran a SQL query that shows the details of the other witness that lived in the last house on Northwestern Dr.
display(Image(filename='screenshots/Screenshot 2026-05-24 104043.png'))

# %% [markdown]
# Now that I had found the names of the two witnesses, I wanted to see if I could find more information about their appearance.

# %%
# Ran a SQL query that shows the details of the witnesses' appearance
display(Image(filename='screenshots/Screenshot 2026-05-24 105241.png'))

# %% [markdown]
# This is interesting information, but I started to wonder if they had frequented the same events on 01/15/2018.

# %%
# Ran a SQL query that shows information about the events that these witnesses attended on 01/15/2018
display(Image(filename='screenshots/Screenshot 2026-05-24 110401.png'))

# %% [markdown]
# Hmmmm, they both attended The Funky Grooves Tour on the same day. Who else was in attendance at the same event?

# %%
# Ran a SQL query that shows information about who else attended the same event on the same day as the witnesses
display(Image(filename='screenshots/Screenshot 2026-05-24 111026.png'))

# %% [markdown]
# Who is person_id 67318?

# %%
# Ran a SQL query that shows information about who else attended the same event on the same day as the witnesses
display(Image(filename='screenshots/Screenshot 2026-05-24 111512.png'))

# %% [markdown]
# We've got a name! Jeremy Bowers...I'm now interested in seeing what these three people said when they were interviewed.

# %%
# Ran a SQL query that shows information about who else attended the same event on the same day as the witnesses
display(Image(filename='screenshots/Screenshot 2026-05-24 112209.png'))

# %% [markdown]
# Okay, Jeremy seems to admit that he commited the murder during the interview. Let's check to see if he was indeed the murderer.

# %%
# Ran a SQL query that shows information about who else attended the same event on the same day as the witnesses
display(Image(filename='screenshots/Screenshot 2026-05-24 112825.png'))

# %% [markdown]
# The murderer has been found! However, there was another person that was the brains behind the operation.
